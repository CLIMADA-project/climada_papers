# %% [markdown]
# # Investigate exposure properties
#
# This notebook investigates exposure properties for wheat and grapevine and plots Figure A2 of the paper (inflation factor). This Notebook requires climada.

# %%
#own
import sys
from pathlib import Path
#add path to path of current skript, where also utility.py lies
sys.path.append(Path.cwd().absolute())
#own utility functions
from utility import exposure_from_gpd
# others
import numpy as np
import matplotlib.pyplot as plt
from utility import en_names
import pandas as pd
from climada.util.api_client import Client

# %% [markdown]
# Load exposure data for all crops and different resolutions

# %%
figdir = 'C:/Users/F80840370/projects/scClim/climada/scClim/subproj_D/papers/NHESS/fig/'
croptypes = ['wheat','grapevine','barley','field_crops','maize','rapeseed'] 
client=Client()

resolutions=[1,2,4,8]
exposures={}
for croptype in croptypes:
    exposures[croptype]={res:{} for res in resolutions}

    #if croptype=='grapevine':
    #    resolution=1
    #else:
    #    resolution=8

    for resolution in resolutions:
        exposures[croptype][resolution] = client.get_exposures('crops', properties={'res_km': f'{resolution}', 'crop': croptype})
# Out:
# 2024-03-05 08:26:49,556 - climada.util.api_client - WARNING - there is no internet connection but the client has stored the results of this very request sometime in the past.
# 2024-03-05 08:26:49,857 - climada.util.api_client - WARNING - there is no internet connection but the client has stored the results of this very request sometime in the past.
# 2024-03-05 08:26:49,969 - climada.util.api_client - WARNING - there is no internet connection but the client has stored the results of this very request sometime in the past.
# 2024-03-05 08:26:50,016 - climada.util.api_client - WARNING - there is no internet connection but the client has stored the results of this very request sometime in the past.
# 2024-03-05 08:26:50,064 - climada.util.api_client - WARNING - there is no internet connection but the client has stored the results of this very request sometime in the past.
# 2024-03-05 08:26:50,156 - climada.util.api_client - WARNING - there is no internet connection but the client has stored the results of this very request sometime in the past.
# 2024-03-05 08:26:50,228 - climada.util.api_client - WARNING - there is no internet connection but the client has stored the results of this very request sometime in the past.
# 2024-03-05 08:26:50,284 - climada.util.api_client - WARNING - there is no internet connection but the client has stored the results of this very request sometime in the past.
# 2024-03-05 08:26:50,332 - climada.util.api_client - WARNING - there is no internet connection but the client has stored the results of this very request sometime in the past.
# ---------------------------------------------------------------------------
# NoConnection                              Traceback (most recent call last)
# Cell In[28], line 16
#      10 #if croptype=='grapevine':
#      11 #    resolution=1
#      12 #else:
#      13 #    resolution=8
#      15 for resolution in resolutions:
# ---> 16     exposures[croptype][resolution] = client.get_exposures('crops', properties={'res_km': f'{resolution}', 'crop': croptype})
#
# File c:\users\f80840370\climada_python\climada\util\api_client.py:877, in Client.get_exposures(self, exposures_type, name, version, properties, status, dump_dir)
#     872 if not exposures_type in EXP_TYPES:
#     873     raise ValueError(
#     874         "Valid exposures types are a subset of CLIMADA exposures types."
#     875         f" Currently these types are supported: {EXP_TYPES}"
#     876     )
# --> 877 dataset = self.get_dataset_info(
#     878     data_type=exposures_type,
#     879     name=name,
#     880     version=version,
#     881     properties=properties,
#     882     status=status,
#     883 )
#     884 return self.to_exposures(dataset, dump_dir)
#
# File c:\users\f80840370\climada_python\climada\util\api_client.py:457, in Client.get_dataset_info(self, data_type, name, version, properties, status)
#     425 def get_dataset_info(
#     426     self, data_type=None, name=None, version=None, properties=None, status="active"
#     427 ):
#     428     """Find the one dataset that matches the given parameters.
#     429
#     430     Parameters
#    (...)
#     455         when there is no dataset matching the search parameters
#     456     """
# --> 457     jarr = self.list_dataset_infos(
#     458         data_type=data_type,
#     459         name=name,
#     460         version=version,
#     461         properties=properties,
#     462         status=status,
#     463     )
#     464     if len(jarr) > 1:
#     465         shown = 10
#
# File c:\users\f80840370\climada_python\climada\util\api_client.py:418, in Client.list_dataset_infos(self, data_type, name, version, properties, status)
#     414 if straight_props:
#     415     params.update(straight_props)
#     417 datasets = [
# --> 418     DatasetInfo.from_json(ds) for ds in self._request_200(url, params=params)
#     419 ]
#     421 if datasets and multi_props:
#     422     return self._filter_datasets(datasets, multi_props)
#
# File c:\users\f80840370\climada_python\climada\util\api_client.py:341, in Client._request_200(self, url, params)
#     339 cached_result = self.cache.fetch(url, **params)
#     340 if not cached_result:
# --> 341     raise Client.NoConnection(
#     342         "there is no internet connection and the client has not"
#     343         " found any cached result for this request."
#     344     )
#     345 LOGGER.warning(
#     346     "there is no internet connection but the client has stored the results"
#     347     " of this very request sometime in the past."
#     348 )
#     349 return cached_result
#
# NoConnection: there is no internet connection and the client has not found any cached result for this request.

# %% [markdown]
# Plot a histogram of the number of fields. With coarser resolution, the distributions changes. For grapevine, the fraction of grid cells with only one field remains high even though area of the gridcell is strongly increased. For wheat, the distribution changes towards a longer tail and higher overall numbers of fields.

# %%
fig,axes=plt.subplots(4,1,sharex=True)
h=axes[0].hist(exposures['grapevine'][1].gdf['n_fields'],bins=np.arange(0.5,60,1),density=True)
h=axes[1].hist(exposures['grapevine'][2].gdf['n_fields'],bins=np.arange(0.5,200,1),density=True)
h=axes[2].hist(exposures['grapevine'][4].gdf['n_fields'],bins=np.arange(0.5,200,1),density=True)
h=axes[3].hist(exposures['grapevine'][8].gdf['n_fields'],bins=np.arange(0.5,200,1),density=True)

# %%
fig,axes=plt.subplots(4,1,sharex=True)
h=axes[0].hist(exposures['wheat'][1].gdf['n_fields'],bins=np.arange(0.5,40,1),density=True)
h=axes[1].hist(exposures['wheat'][2].gdf['n_fields'],bins=np.arange(0.5,100,1),density=True)
h=axes[2].hist(exposures['wheat'][4].gdf['n_fields'],bins=np.arange(0.5,100,1),density=True)
h=axes[3].hist(exposures['wheat'][8].gdf['n_fields'],bins=np.arange(0.5,100,1),density=True)

# %% [markdown]
# This suggests that, the total area covered by all grid points of the exposure (exposure area) strongly increases (is inflated) with coarser resolution for grapevine but less so for wheat. Lets investigate this  for two crops (wheat, grapevine) and an $n_{thresh}$ of 1. We compute for each resolution the area covered by all exposure gridpoints relative to the area of all exposure gridpoints at 1km. This is what we call inflation factor.

# %%
exp_thresh=1
res=[1,2,4,8]

tot_area_fraction={c:[] for c in exposures.keys()}
inflation={c:[] for c in exposures.keys()}

for r in res:
    for c in exposures.keys():
        print(c, r,'km')
        exp=exposures[c][r].gdf[exposures[c][r].gdf['value']>=exp_thresh]
        exp1=exposures[c][1].gdf[exposures[c][1].gdf['value']>=exp_thresh]
        tot_area_fraction[c].append(exp['area_ha'].sum()/(100*exp['value'].size*r*r))
        inflation[c].append(exp['value'].size*r*r/exp1['value'].size)

tot_area_fraction['res']=res
inflation['res']=res
data_fraction=pd.DataFrame.from_dict(data=tot_area_fraction)
data_inflation=pd.DataFrame.from_dict(data=inflation)
# Out:
# wheat 1 km
# grapevine 1 km
# wheat 2 km
# grapevine 2 km
# wheat 4 km
# grapevine 4 km
# wheat 8 km
# grapevine 8 km

# %% [markdown]
# Now plot the inflation factor. This is Figure A2 of the paper.

# %%
fig,ax=plt.subplots(figsize=(7,4))
ax.plot(data_inflation['wheat'],label='wheat',marker='x')
ax.plot(data_inflation['grapevine'],label='grapevine',marker='x',color='dimgrey',linestyle='dotted')
ax.set_xticks(data_inflation.index)
ax.set_xticklabels(['1km','2km','4km','8km'])
ax.set_xlabel('resolution')
ax.set_ylabel('inflation factor')
ax.legend()

# %%
fig.savefig(f'{figdir}/Figure_inflation_factor.png',dpi=200,bbox_inches='tight')
fig.savefig(f'{figdir}/Figure_inflation_factor.pdf',dpi=200,bbox_inches='tight')

# %% [markdown]
# Finally we can look at some interesting characteristics of the distributions for wheat and grapevine at different resolutions

# %%
exp_densities_n={c: [] for c in exposures.keys()}
exp_densities_ha={c: [] for c in exposures.keys()}
exp_densities_n_q={c: [] for c in exposures.keys()}
n_one_field={c: [] for c in exposures.keys()}
n_n_field={c: [] for c in exposures.keys()}

for c in exposures.keys():
    for res in resolutions:
        exp_densities_n[c].append(exposures[c][res].gdf.n_fields.mean()/(res*res))
        exp_densities_ha[c].append(exposures[c][res].gdf['area_ha'][exposures[c][res].gdf['n_fields']>=exp_thresh].mean()/(res*res*100)) #(exposures[c][res].gdf.area_ha.mean()/(res*res))

        p50=exposures[c][res].gdf.n_fields.quantile(q=0.5)
        exp_densities_n_q[c].append(exposures[c][res].gdf.n_fields[exposures[c][res].gdf.n_fields<p50].mean()/(res*res))
        n_one_field[c].append(exposures[c][res].gdf.n_fields[exposures[c][res].gdf.n_fields==1].count()/len(exposures[c][res].gdf))
        n_n_field[c].append(exposures[c][res].gdf.n_fields[exposures[c][res].gdf.n_fields<=10].count()/len(exposures[c][res].gdf))

# %% [markdown]
# For example the fraction of grid cells with only one field

# %%
n_n_field
# Out:
# {'wheat': [0.9294507085962553,
#   0.5293542074363993,
#   0.2883046237533998,
#   0.2398921832884097],
#  'grapevine': [0.6351763169351328,
#   0.5884645362431801,
#   0.5318840579710145,
#   0.42765273311897106]}

# %% [markdown]
# Or the fraction of grid cells with less than 10 fields

# %%
n_n_field
# Out:
# {'wheat': [0.9294507085962553,
#   0.5293542074363993,
#   0.2883046237533998,
#   0.2398921832884097],
#  'grapevine': [0.6351763169351328,
#   0.5884645362431801,
#   0.5318840579710145,
#   0.42765273311897106]}

# %% [markdown]
# Or the average cropland number and area densities

# %%
exp_densities_n
# Out:
# {'wheat': [4.567601117202855,
#   3.0555283757338554,
#   2.5019832275611966,
#   1.8596276954177897],
#  'grapevine': [36.73008271658685,
#   16.439789555728762,
#   7.642119565217391,
#   4.238796221864952]}

# %%
exp_densities_ha
# Out:
# {'wheat': [0.07275252805318928,
#   0.05128369056691585,
#   0.039851466947539715,
#   0.029620059328258966],
#  'grapevine': [0.0540474426964753,
#   0.024190759133632844,
#   0.011245197090018455,
#   0.006237287775010238]}

# %% [markdown]
# or the median number density

# %%
exp_densities_n_q
# Out:
# {'Weizen': [1.8482367758186398,
#   1.0504716981132076,
#   0.6620412844036697,
#   0.3236486486486487],
#  'Reben': [1.8252516010978956,
#   0.474,
#   0.15090090090090091,
#   0.07648026315789473]}

# %% [markdown]
# Now lets investigate how increasing the minimum number of fields within a grid cell $n_{thresh}$ reduces the fraction of total crop area included in the exposure. Lets compute this fraction in terms of area fraction and fraction of fields. For that we re-read the exposure data to include all crops and focus on spatial resolutions of 1km and 8km

# %% [markdown]
# Get the fractions for exposure thresholds between 1 and 300 and resolution of 1km for grapevine and 8km for wheat.

# %%
#get data
exposure_threshs=np.arange(1,300,2)
area_fraction={}
n_fraction={}

#loop over all crops
for c in exposures.keys():
     print(c)
     if c=='grapevine':
             res=1
     else: 
             res=8
     af=[] #area fraction
     nf=[] #number fraction
     for exp_thresh in exposure_threshs:
          af.append(exposures[c][res].gdf[exposures[c][res].gdf['value']>=exp_thresh]['area_ha'].sum()/exposures[c][res].gdf['area_ha'].sum())
          nf.append(exposures[c][res].gdf[exposures[c][res].gdf['value']>=exp_thresh]['value'].sum()/exposures[c][res].gdf['value'].sum())
     
     #fill dictionary and set names
     if c not in ['wheat','grapevine','field_crops','barley','rapeseed','maize']:
            name=en_names[c]
     else: 
            name=c
     area_fraction[f'{name} ({res}km)']=af
     n_fraction[f'{name} ({res}km)']=nf

#create pandas Dataframe with exposure threshold as index and fractions for each croptypes as columns
area_fraction['exp_thresh']=exposure_threshs
data_area_fraction=pd.DataFrame.from_dict(data=area_fraction)
n_fraction['exp_thresh']=exposure_threshs
data_n_fraction=pd.DataFrame.from_dict(data=n_fraction)

#create subsets of these Dataframes to facilitate plotting

#number fraction
df=data_n_fraction.set_index('exp_thresh')
df_grapevine=df['grapevine (1km)']
df_field=df['field crops (1km)']
df=df.drop('grapevine (1km)',axis=1)
df=df.drop('field crops (1km)',axis=1)

#area fraction
df2=data_area_fraction.set_index('exp_thresh')
df2_grapevine=df2['grapevine (1km)']
df2_field=df2['field crops (1km)']
df2=df2.drop('grapevine (1km)',axis=1)
df2=df2.drop('field crops (1km)',axis=1)
# Out:
# wheat
# grapevine
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\F80840370\Anaconda3\envs\climada_env_3.9\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\F80840370\Anaconda3\envs\climada_env_3.9\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\F80840370\Anaconda3\envs\climada_env_3.9\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'field crops (1km)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 38
#      36 df=data_n_fraction.set_index('exp_thresh')
#      37 df_grapevine=df['grapevine (1km)']
# ---> 38 df_field=df['field crops (1km)']
#      39 df=df.drop('grapevine (1km)',axis=1)
#      40 df=df.drop('field crops (1km)',axis=1)
#
# File c:\Users\F80840370\Anaconda3\envs\climada_env_3.9\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File c:\Users\F80840370\Anaconda3\envs\climada_env_3.9\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'field crops (1km)'

# %%
df
# Out:
#             wheat (8km)  grapevine (1km)
# exp_thresh
# 1                   1.0              1.0
# 3                   0.0              0.0
# 5                   0.0              0.0
# 7                   0.0              0.0
# 9                   0.0              0.0
# ...                 ...              ...
# 291                 0.0              0.0
# 293                 0.0              0.0
# 295                 0.0              0.0
# 297                 0.0              0.0
# 299                 0.0              0.0
#
# [150 rows x 2 columns]

# %% [markdown]
# Now plot this in a Figure (Figure A3 of the paper)

# %%
labels=['a)','b)']
#fontsizes
font_s=14
font_l=20
import matplotlib
matplotlib.rcParams.update({'font.size': font_s, 'axes.labelsize':font_s})

fig,axs=plt.subplots(1,2,figsize=(12,5))
plt.subplots_adjust(wspace=0.15)
df.plot(ax=axs[0],linewidth=2)

df_field.plot(ax=axs[0],linewidth=2,color='k',linestyle='dashed')

df_grapevine.plot(ax=axs[1],color='dimgrey',linewidth=2,label='grapevine (1km, number)')
df2_grapevine.plot(ax=axs[1],color='dimgrey',linewidth=2,linestyle='dashed',label='grapevine (1km, area)')
axs[1].legend()
axs[0].legend()
axs[0].set_ylabel('fraction of total cropland')
#plot horizontal thresholds
axs[0].axvline(x=20,color='dimgrey',linestyle='dotted')
axs[1].axvline(x=10,color='dimgrey',linestyle='dotted')
for i,ax in enumerate(axs):
    ax.text(0,1.05,labels[i],
                    transform=ax.transAxes,fontweight='bold')
    ax.set_xlabel(r'n$_{thresh}$')
    ax.set_ylim(0,1.1)
    ax.set_yticks(np.arange(0.,1.1,0.1))

# %%
fig.savefig(f'{figdir}/Figure_A3.png',dpi=200,bbox_inches='tight')
fig.savefig(f'{figdir}/Figure_A3.pdf',dpi=200,bbox_inches='tight')
